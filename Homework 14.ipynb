# %% [markdown]
# ### Chapter 10 Problems 8 and 9

# %% [markdown]
# ## 10-8
# The catalytic dehydration of methanol (ME) to form dimethyl ether (DME) and water was carried out over an ion exchange catalyst. The packed bed was initially filled with nitrogen, and at *t* = 0. The N$_2$ feed is switched to pure methanol vapor entering the reactor at 413 K, 100 kPa, and 0.2 cm$^3$/s. The following partial pressures were recorded at the exit to the differential reactor containing 1.0 g of catalyst in 4.5 cm$^3$ of reactor volumes

# %% [markdown]
# $$ 2 CH_3 OH \rightarrow CH_3 OCH_3 + H_2 O$$
# $$ \text{2 ME} \rightarrow \text{DME} + H_2 O $$

# %% [markdown]
# | t(s)   | 0 | 10 | 50 | 100 | 150 | 200 | 300|
# |--------|---|----|----|-----|-----|-----|----|
# |P$_{N_2}$| 100 | 50 | 10 | 2 | 0 | 0 | 0|
# | P $_{ME}$ | 0 | 2 | 15 | 23 | 25 | 26 | 25|
# | P$_{H_2O}$| 0 | 10 | 15 | 30 | 35 | 37 | 37|
# | P$_{DME}$ | 0 | 38 | 60 | 45 | 40 | 37 | 37 |

# %% [markdown]
# Use parts (a) through (f) to lead you to suggest a mechanism, rate-limiting step, and rate law consistent with this data.
# - a) Using the data above, sketch the exit concetrations as a function of time
# - b) Which species took longer than others to exit the reactor in the gas phase? What could have caused this difference in exit times?
# - c) What species are adsorbed on the surface?
# - d) Are any species not adsorbed on the surface? If so, which ones?
# - e) Which set of figures, (1)-(4) below, correctly describe the functionality of the chemical reaction rate with the partial pressures $P_W$, $P_{DME}$, and $P_{ME}$?
# - f) Derive the rate law for the catalytic dehydration of methanol. Dimethyl Either 2 ME $\rightarrow$ DME + W.

# %%
import matplotlib.pyplot as plt

t =     [  0, 10, 50, 100, 150, 200, 300]
P_N2 =  [100, 50, 10,   2,   0,   0,   0]
P_ME =  [  0,  2, 15,  23,  25,  26,  26]
P_H2O = [  0, 10, 15,  30,  35,  37,  37]
P_DME = [  0, 38, 60,  45,  40,  37,  37]

plt.plot(t, P_N2, label='Nitrogen')
plt.plot(t, P_ME, label='Methanol')
plt.plot(t, P_H2O, label='Steam')
plt.plot(t, P_DME, label='Dimethal Ether')
plt.xlabel("time (s)")
plt.ylabel("Pressure kPa")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %% [markdown]
# Dimethal Ether looks like it took the longes to exit out of the reactor.

# %% [markdown]
# ## Probelem 10-9
# (a)
# (b) This would be incorrect  since the goal is to remove CO as a fraction of byproduct and not the overall conversion rate of CO to its final product.
# (c) It really depends on the type of hybrid. If it is a standard mild-hybrid the problem will still persist but if the cars are plug in hybrids it may rarely pop up again.
